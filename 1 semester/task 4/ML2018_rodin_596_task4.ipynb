# %%
#Использовался google colab
from google.colab import files
# !pip install -U -q PyDrive
# !pip install imbalanced-learn
# !pip install kaggle

# %%
files.upload()
# Out:
#      <input type="file" id="files-ba0a8c43-05c5-404d-9233-8ea3bee8e3b7" name="files[]" multiple disabled />
#      <output id="result-ba0a8c43-05c5-404d-9233-8ea3bee8e3b7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving class_magnesium_not_drop_na.py to class_magnesium_not_drop_na.py
# {'class_magnesium_not_drop_na.py': b'import numpy as np\nimport pandas as pd\n\nimport matplotlib\nimport matplotlib.pyplot as plt\nimport matplotlib.patches as mpatches\nget_ipython().magic(\'matplotlib inline\')\n\nimport os\nfrom copy import deepcopy\n\nfrom sklearn.model_selection import GroupKFold, GroupShuffleSplit\nfrom sklearn.ensemble import RandomForestClassifier\nfrom sklearn.model_selection import GridSearchCV, StratifiedShuffleSplit\nfrom sklearn.feature_selection import SelectFromModel\n\nfrom sklearn.metrics import classification_report, accuracy_score, confusion_matrix, roc_auc_score\nfrom sklearn.metrics import roc_curve, precision_recall_curve, average_precision_score, f1_score\n\ntry:\n    from tqdm import tnrange, tqdm_notebook\n    tqdm = True\nexcept ImportError:\n    tqdm = False\n    pass\n\nfrom matplotlib import colors as mcolors\nfrom matplotlib import cm\nimport random\n\nimport re\n\nimport itertools\nfrom sklearn.utils.multiclass import check_classification_targets\n\nfrom imblearn.under_sampling import RandomUnderSampler\n\nfrom scipy.stats.kde import gaussian_kde\nfrom scipy.optimize import brentq\nfrom numpy import linspace\n\nimport pickle\n\nimport sys\nfrom IPython.core.display import clear_output\ndef change_output(x):\n    clear_output()\n    sys.stdout.write(x)\n    sys.stdout.flush()\n\ncolour = [\'#fc977c\', \'#929292\']\n\nclass Magnesium(object):\n    def __init__(self, file_, fold = "rna-ion-step2/", model = None, colours = [\'#fc977c\', \'#929292\'], name = \'\'):\n        \'\'\'\n            \xd0\x9a\xd0\xbb\xd0\xb0\xd1\x81\xd1\x81 Magnesium \xd0\xb7\xd0\xb0\xd0\xb3\xd1\x80\xd1\x83\xd0\xb6\xd0\xb0\xd0\xb5\xd1\x82 \xd0\xb4\xd0\xb0\xd0\xbd\xd0\xbd\xd1\x8b\xd0\xb5 \xd0\xb8\xd0\xb7 \xd1\x84\xd0\xb0\xd0\xb9\xd0\xbb\xd0\xb0 file_, \xd0\xbd\xd0\xb0\xd1\x85\xd0\xbe\xd0\xb4\xd1\x8f\xd1\x89\xd0\xb5\xd0\xb3\xd0\xbe\xd1\x81\xd1\x8f \xd0\xb2 \xd0\xbf\xd0\xb0\xd0\xbf\xd0\xba\xd0\xb5 fold. \xd0\x94\xd0\xb5\xd0\xbb\xd0\xb0\xd0\xb5\xd1\x82 dropna (\xd1\x87\xd1\x82\xd0\xbe\xd0\xb1\xd1\x8b \xd0\xba\xd0\xb0\xd1\x81 \xd0\xbd\xd0\xb5 \xd1\x80\xd1\x83\xd0\xb3\xd0\xb0\xd0\xbb\xd1\x81\xd1\x8f)\n            model - \xd0\xbc\xd0\xbe\xd0\xb4\xd0\xb5\xd0\xbb\xd1\x8c, \xd1\x81 \xd0\xba\xd0\xbe\xd1\x82\xd0\xbe\xd1\x80\xd0\xbe\xd0\xb9 \xd0\xb2\xd1\x8b \xd1\x85\xd0\xbe\xd1\x82\xd0\xb8\xd1\x82\xd0\xb5 \xd1\x80\xd0\xb0\xd0\xb1\xd0\xbe\xd1\x82\xd0\xb0\xd1\x82\xd1\x8c\xd0\xb1 \xd0\xbf\xd0\xbe \xd1\x83\xd0\xbc\xd0\xbe\xd0\xbb\xd1\x87\xd0\xb0\xd0\xbd\xd0\xb8\xd1\x8e RFC\n            \xd0\xa1\xd0\xbe\xd1\x85\xd1\x80\xd0\xb0\xd0\xbd\xd1\x8f\xd0\xb5\xd1\x82 \xd0\xbf\xd0\xb5\xd1\x80\xd0\xb5\xd0\xbc\xd0\xb5\xd0\xbd\xd0\xbd\xd1\x8b\xd0\xb5:\n            data - \xd0\xb7\xd0\xb0\xd0\xb3\xd1\x80\xd1\x83\xd0\xb6\xd0\xb5\xd0\xbd\xd0\xbd\xd1\x8b\xd0\xb9 DataFrame\n            features - \xd0\xbf\xd1\x80\xd0\xb8\xd0\xb7\xd0\xbd\xd0\xb0\xd0\xba\xd0\xb8\n            groups - \xd1\x86\xd0\xb5\xd0\xbf\xd0\xbe\xd1\x87\xd0\xba\xd0\xb8\n            x - \xd0\xb4\xd0\xb0\xd0\xbd\xd0\xbd\xd1\x8b\xd0\xb5 \xd0\xb4\xd0\xbb\xd1\x8f \xd0\xb1\xd1\x83\xd1\x87\xd0\xb5\xd0\xbd\xd0\xb8\xd1\x8f \xd0\xb2 \xd0\xb2\xd0\xb8\xd0\xb4\xd0\xb5 Numpy-\xd0\xbc\xd0\xb0\xd1\x82\xd1\x80\xd0\xb8\xd1\x86\xd1\x8b\n            y - \xd1\x86\xd0\xb5\xd0\xbb\xd0\xb5\xd0\xb2\xd0\xbe\xd0\xb9 \xd0\xbf\xd1\x80\xd0\xb8\xd0\xb7\xd0\xbd\xd0\xb0\xd0\xba\n        \'\'\'\n        self.filename = file_.split(\'.csv\')[0]\n        if model is not None:\n            self.model = model            \n        else:\n            self.model = RandomForestClassifier(n_jobs=-1)\n        self.colours = colours\n        self.model_name = str(self.model).split(\'(\')[0]\n        self.trained_model = None\n        change_output(\'Loading data...\')        \n        self.data = pd.read_table(fold+file_)\n        change_output(\'Data processing...\')  \n        if (\'DSSR\' in self.data.columns):\n            self.data.drop(\'DSSR\', axis=1, inplace=True)            \n        self.data = self.data.d ...

# %%
# !mv kaggle.json /content/.kaggle/

# %%
# !kaggle competitions download -c ml-mipt-spring2018-1
# Out:
# Warning: Your Kaggle API key is readable by other users on this system! To fix this, you can run 'chmod 600 /content/.kaggle/kaggle.json'
# train.csv: Skipping, found more recently modified local copy (use --force to force download)
# sample_submission.csv: Skipping, found more recently modified local copy (use --force to force download)
# test.csv: Skipping, found more recently modified local copy (use --force to force download)

# %%
# !mv /content/.kaggle/competitions/ml-mipt-spring2018-1/* /content/

# %%
import numpy as np
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_selection import SelectFromModel
from sklearn.feature_selection import VarianceThreshold
from imblearn.under_sampling import RandomUnderSampler
import sklearn

import sys
sys.path.insert(0, 'basic_codes')

import class_magnesium_not_drop_na #_transform_pairings
from class_magnesium_not_drop_na import *
import pandas as pd

def load_data(filename):
    '''
        Функция для загрузки датасета без инициализации класса. 
        
        Возвращает:
         data - полный DataFrame
         fetures - список признаков для обучения/предсказания
         x - датасет для тренировки/предсказания в формате np.array
         y - целевой признак, если он есть. В случае с тестовым датасетом возвращает None
    '''
    
    data = pd.read_table(filename, sep=',').dropna()    
    
    data = data[~(data['chainlen']>1000)]

    if ('DSSR' in data.columns):
        data.drop('DSSR', axis=1, inplace=True)    
    
    features = list(deepcopy(data.columns))
    [features.remove(column) for column in ['Id','index', 'pdb_chain', 'mg'] if column in data.columns];
    x_test = np.array(data[features])
    
    try:
        y_test = np.array(data['mg'])
    except: 
        y_test = None
    change_output('Data loaded')
    return {'data':data, 'features':features, 'x':x_test, 'y':y_test}

# %%
fold = ''
file_train = 'train.csv'
file_test = 'test.csv'
estimators=1500
m = Magnesium(file_train, fold = fold, model = AdaBoostClassifier(n_estimators=estimators))
# Out:
# Everything is OK. Ready for your experiments!

# %%
# %%time
rm_model = RandomForestClassifier(n_estimators=20).fit(m.x, m.y)
sfm = SelectFromModel(rm_model, prefit=True)
x = sfm.transform(m.x)
rus = RandomUnderSampler(random_state=42)
x_res, y_res = rus.fit_sample(x, m.y)
# Out:
# CPU times: user 34.9 s, sys: 0 ns, total: 34.9 s
# Wall time: 34.9 s

# %%
# %%time
m.trained_model = deepcopy(m.model)
m.trained_model.fit(x_res, y_res)
# Out:
# CPU times: user 6min 5s, sys: 53 ms, total: 6min 5s
# Wall time: 6min 5s

# %%
predict_train =  m.predict(x = x, 
                           y = m.y,
                           model=m.trained_model, 
                           plots = True)

# %%
test = load_data(fold+file_test)
test_x = sfm.transform(test['x'])
pred = m.trained_model.predict(test_x)
df = pd.DataFrame(pred, columns =['mg'])
df.index.name='Id'
df.to_csv('result.csv')
files.download('result.csv')
# Out:
# Data loaded
